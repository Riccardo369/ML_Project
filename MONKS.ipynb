# %% [markdown]
# # MONKS problems

# %% [markdown]
# This notebook is meant to analyze the first three monk problems.

# %%
# Out:
# {'a1': {1: array([1., 0., 0.]), 2: array([0., 1., 0.]), 3: array([0., 0., 1.])}, 'a2': {1: array([1., 0., 0.]), 2: array([0., 1., 0.]), 3: array([0., 0., 1.])}, 'a3': {1: array([1., 0.]), 2: array([0., 1.])}, 'a4': {1: array([1., 0., 0.]), 2: array([0., 1., 0.]), 3: array([0., 0., 1.])}, 'a5': {1: array([1., 0., 0., 0.]), 2: array([0., 1., 0., 0.]), 3: array([0., 0., 1., 0.]), 4: array([0., 0., 0., 1.])}, 'a6': {1: array([1., 0.]), 2: array([0., 1.])}, 'class': {0: array([1., 0.]), 1: array([0., 1.])}}
# [array([1., 0., 0.]), array([1., 0., 0.]), array([1., 0.]), array([1., 0., 0.]), array([0., 0., 1., 0.]), array([1., 0.])] [1 1 1 1 3 1]
# [array([1., 0., 0.]), array([1., 0., 0.]), array([1., 0.]), array([1., 0., 0.]), array([0., 0., 1., 0.]), array([0., 1.])] [1 1 1 1 3 2]
# [array([1., 0., 0.]), array([1., 0., 0.]), array([1., 0.]), array([0., 0., 1.]), array([0., 1., 0., 0.]), array([1., 0.])] [1 1 1 3 2 1]
# ...
